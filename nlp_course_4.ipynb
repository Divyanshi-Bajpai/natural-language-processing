# %%
VECTORIZATION

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect=CountVectorizer()
mess=['Hey,let us go a game today',' Call your sister', 'Hope you are doing good']
vect.get_feature_names(mess)
