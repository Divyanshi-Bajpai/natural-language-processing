# %% [markdown]
# STEMMING AND LEMMATIZATION

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()
print("Socks: ",lem.lemmatize('socks'))
print("butterflies: ",lem.lemmatize('butterflies'))
# Out:
# Socks:  sock
# butterflies:  butterfly

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
word=['running','likes','ran','happily']
for i in word:
  print(i,":",ps.stem(i))
# Out:
# running : run
# likes : like
# ran : ran
# happily : happili

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer(language='english')
words_to_stem = ['butterflies', 'jumped', 'hi fived', 'foxes']
for words in words_to_stem:
  print(words+" --> "+stemmer.stem(words))
# Out:
# butterflies --> butterfli
# jumped --> jump
# hi fived --> hi fiv
# foxes --> fox

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer(language='english')
